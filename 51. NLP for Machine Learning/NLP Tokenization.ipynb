# %% [markdown]
# # NLP Tokenization with NLTK

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\thinkpad\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\users\thinkpad\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\users\thinkpad\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\thinkpad\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\users\thinkpad\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\thinkpad\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
corpus = """Hello welcome, to Uzair khan NLP Learnign Coures! 
Please watch the practice the coures to become expert in NLP. """

# %%
corpus
# Out:
# 'Hello welcome, to Uzair khan NLP Learnign Coures. \nPlease watch the practice the coures to become expert in NLP. '

# %% [markdown]
# ## Tokenization
#  **Paragrapht ------>  Sentence**

# %%
from nltk.tokenize import sent_tokenize

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Thinkpad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Thinkpad\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
documents = sent_tokenize(corpus)
print(documents)
# Out:
# ['Hello welcome, to Uzair khan NLP Learnign Coures!', 'Please watch the practice the coures to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %% [markdown]
#  **Paragrapht ------>  Sentence**
#  **Sentence ------>  words**

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Uzair',
#  'khan',
#  'NLP',
#  'Learnign',
#  'Coures',
#  '!',
#  'Please',
#  'watch',
#  'the',
#  'practice',
#  'the',
#  'coures',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'welcome', ',', 'to', 'Uzair', 'khan', 'NLP', 'Learnign', 'Coures', '!']
# ['Please', 'watch', 'the', 'practice', 'the', 'coures', 'to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Uzair',
#  'khan',
#  'NLP',
#  'Learnign',
#  'Coures',
#  '!',
#  'Please',
#  'watch',
#  'the',
#  'practice',
#  'the',
#  'coures',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'welcome',
#  ',',
#  'to',
#  'Uzair',
#  'khan',
#  'NLP',
#  'Learnign',
#  'Coures',
#  '!',
#  'Please',
#  'watch',
#  'the',
#  'practice',
#  'the',
#  'coures',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
